# %% [markdown]
# # Scraping of Cars Information from Autolist site

# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - CURL

# %%
response = requests.get('https://www.autolist.com/api/cwv/seo/listings?make=Tesla&location=Mumbai,%20MH&latitude=19.0748&longitude=72.8856&radius=50&page=1')

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json = response.json()

# %%
type(results_json)
# Out:
# dict

# %%
results_json
# Out:
# {'total_results_count': 522,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2023,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://www.autolist.com/listings#latitude=19.0748&location=Mumbai%2C+MH&longitude=72.8856&make=Tesla&page=1&radius=50'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1661466679,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/7SAYGDEE6NF462505',
#    'vdp_url': '/tesla-model+y#vin=7SAYGDEE6NF462505',
#    'clickoff_url': 'https://www.carmax.com/car/22985144?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 249428373,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/22985144/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--QBH-ymJb--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/22985144/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 40.430227,
#    'lon': -104.994554,
#    'year': 2022,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$79,998',
#    'price_unformatted': 79998,
#    'mileage': '274 Miles',
#    'mileage_unformatted': 274,
#    'city': 'Loveland',
#    'state': 'CO',
#    'distance_from_origin': 8323,
#    'dealer_name': 'CarMax Loveland - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '7SAYGDEE6NF462505',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '7SAYGDEE6NF462505',
#     'remote_dealer_id': '7258',
#     'dealer_name': 'CarMax Loveland',
#     'remote_sku': '22985144',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_loveland',
#     'dealer_uuid': '03f9527d-f781-463e-ab42-13b6dac177d6',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1661293004,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB5KF389947',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB5KF389947',
#    'clickoff_url': 'https://www.carmax.com/car/23080315?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 249279602,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23080315/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--bgZYKItv--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23080315/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 39.6665791047802,
#    'lon': -84.24308234220828,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$53,998',
#    'price_unformatted': 53998,
#    'mileage': '32,634 Miles',
#    'mileage_unformatted': 32634,
#    'city': 'West Carrollton',
#    'state': 'OH',
#    'distance_from_origin': 8118,
#    'dealer_name': 'CarMax Dayton - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB5KF389947',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB5KF389947',
#     'remote_dealer_id': '7240',
#     'dealer_name': 'CarMax Dayton',
#     'remote_sku': '23080315',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_dayton',
#     'dealer_uuid': '13214bb8-58f3-43ed-b68f-c53e365159b4',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1661940954,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEF0LF014067',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEF0LF014067',
#    'clickoff_url': 'https://www.carmax.com/car/22955485?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 249739165,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/22955485/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4p_Ibb-X--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/22955485/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.500874,
#    'lon': -121.966481,
#    'year': 2020,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$72,998',
#    'price_unformatted': 72998,
#    'mileage': '6,701 Miles',
#    'mileage_unformatted': 6701,
#    'city': 'Fremont',
#    'state': 'CA',
#    'distance_from_origin': 8410,
#    'dealer_name': 'CarMax Fremont - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDEF0LF014067',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJYGDEF0LF014067',
#     'remote_dealer_id': '6071',
#     'dealer_name': 'CarMax Fremont',
#     'remote_sku': '22955485',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_fremont',
#     'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Performance',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1658917199,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEE3MF099818',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEE3MF099818',
#    'clickoff_url': 'https://www.carmax.com/car/22967426?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 247600541,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/22967426/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--w20-bMTI--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/22967426/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 26.097263,
#    'lon': -80.245949,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$69,998',
#    'price_unformatted': 69998,
#    'mileage': '26,296 Miles',
#    'mileage_unformatted': 26296,
#    'city': 'Davie',
#    'state': 'FL',
#    'distance_from_origin': 8832,
#    'dealer_name': 'CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDEE3MF099818',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJYGDEE3MF099818',
#     'remote_dealer_id': '7108',
#     'dealer_name': 'CarMax Ft. Lauderdale',
#     'remote_sku': '22967426',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_ft_lauderdale',
#     'dealer_uuid': 'e021e97a-0130-48f0-a061-638533e61fbd',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1661811400,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEEXMF207562',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEEXMF207562',
#    'clickoff_url': 'https://www.carmax.com/car/23270613?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 249663285,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23270613/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--cAjkbXIB--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23270613/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 33.90331664977008,
#    'lon': -117.3964790351618,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$69,998',
#    'price_unformatted': 69998,
#    'mileage': '9,772 Miles',
#    'mileage_unformatted': 9772,
#    'city': 'Riverside',
#    'state': 'CA',
#    'distance_from_origin': 8714,
#    'dealer_name': 'CarMax Riverside - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDEEXMF207562',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJYGDEEXMF207562',
#     'remote_dealer_id': '7196',
#     'dealer_name': 'CarMax Riverside',
#     'remote_sku': '23270613',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_riverside',
#     'dealer_uuid': 'f310bc4b-e452-4c1a-8e03-1f6860258ce8',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1662156998,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/7SAYGDEF0NF398275',
#    'vdp_url': '/tesla-model+y#vin=7SAYGDEF0NF398275',
#    'clickoff_url': 'https://www.carmax.com/car/23323313?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 249972032,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23323313/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--MRCaG0wv--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23323313/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 42.049942,
#    'lon': -88.073425,
#    'year': 2022,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$72,998',
#    'price_unformatted': 72998,
#    'mileage': '10,360 Miles',
#    'mileage_unformatted': 10360,
#    'city': 'Schaumburg',
#    'state': 'IL',
#    'distance_from_origin': 8041,
#    'dealer_name': 'CarMax Schaumburg - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '7SAYGDEF0NF398275',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '7SAYGDEF0NF398275',
#     'remote_dealer_id': '7128',
#     'dealer_name': 'CarMax Schaumburg',
#     'remote_sku': '23323313',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_schaumburg',
#     'dealer_uuid': 'fb844ad8-4b8d-42c8-ac30-580cf7f20278',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Performance',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1660213843,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB2KF510319',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB2KF510319',
#    'clickoff_url': 'https://www.carmax.com/car/22954771?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 248526671,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/22954771/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--N2byrKRh--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/22954771/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 37.50613267061532,
#    'lon': -121.965889235115,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$53,998',
#    'price_unformatted': 53998,
#    'mileage': '31,200 Miles',
#    'mileage_unformatted': 31200,
#    'city': 'Fremont',
#    'state': 'CA',
#    'distance_from_origin': 8409,
#    'dealer_name': 'CarMax Fremont - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB2KF510319',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB2KF510319',
#     'remote_dealer_id': '6071',
#     'dealer_name': 'CarMax Fremont',
#     'remote_sku': '22954771',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_fremont',
#     'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1656972914,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDED7MF108978',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDED7MF108978',
#    'clickoff_url': 'https://www.carmax.com/car/22747328?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 246336343,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/22747328/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--ZFPssluj--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/22747328/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 41.71413794620101,
#    'lon': -87.75252481993387,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$67,998',
#    'price_unformatted': 67998,
#    'mileage': '10,307 Miles',
#    'mileage_unformatted': 10307,
#    'city': 'Oak Lawn',
#    'state': 'IL',
#    'distance_from_origin': 8057,
#    'dealer_name': 'CarMax Oak Lawn - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDED7MF108978',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJYGDED7MF108978',
#     'remote_dealer_id': '7199',
#     'dealer_name': 'CarMax Oak Lawn',
#     'remote_sku': '22747328',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_oak_lawn',
#     'dealer_uuid': '0b420e90-299b-493d-b01b-f03b50fa5d0b',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1661985046,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA8MF098255',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA8MF098255',
#    'clickoff_url': 'https://www.carmax.com/car/23000025?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 249788060,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23000025/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--StwQ8pE0--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23000025/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 26.596253,
#    'lon': -81.848842,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$55,998',
#    'price_unformatted': 55998,
#    'mileage': '2,813 Miles',
#    'mileage_unformatted': 2813,
#    'city': 'Fort Myers',
#    'state': 'FL',
#    'distance_from_origin': 8855,
#    'dealer_name': 'CarMax Ft. Myers - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA8MF098255',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA8MF098255',
#     'remote_dealer_id': '6035',
#     'dealer_name': 'CarMax Ft. Myers',
#     'remote_sku': '23000025',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_ft_myers',
#     'dealer_uuid': '393852f4-ca83-4ab0-836a-34b1deba908d',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1660169751,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEE3MF209055',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEE3MF209055',
#    'clickoff_url': 'https://www.carmax.com/car/22999329?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 248508231,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/22999329/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--7ZODzIzq--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/22999329/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 33.67870681721259,
#    'lon': -117.9071677943577,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$69,998',
#    'price_unformatted': 69998,
#    'mileage': '27,897 Miles',
#    'mileage_unformatted': 27897,
#    'city': 'Costa Mesa',
#    'state': 'CA',
#    'distance_from_origin': 8723,
#    'dealer_name': 'CarMax Costa Mesa - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDEE3MF209055',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJYGDEE3MF209055',
#     'remote_dealer_id': '7297',
#     'dealer_name': 'CarMax Costa Mesa',
#     'remote_sku': '22999329',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_costa_mesa',
#     'dealer_uuid': 'a1b00823-902b-4b81-b8ac-d6cb028a5497',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1662200143,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA7MF848275',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7MF848275',
#    'clickoff_url': 'https://www.carmax.com/car/23099154?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 250001837,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23099154/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--8dm_fjcb--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23099154/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 41.287643,
#    'lon': -72.882835,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$54,998',
#    'price_unformatted': 54998,
#    'mileage': '10,523 Miles',
#    'mileage_unformatted': 10523,
#    'city': 'East Haven',
#    'state': 'CT',
#    'distance_from_origin': 7725,
#    'dealer_name': 'CarMax East Haven - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA7MF848275',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA7MF848275',
#     'remote_dealer_id': '7287',
#     'dealer_name': 'CarMax East Haven',
#     'remote_sku': '23099154',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_east_haven',
#     'dealer_uuid': '25323686-f20e-40d3-9336-475a45536e87',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1657836925,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EBXKF389006',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EBXKF389006',
#    'clickoff_url': 'https://www.carmax.com/car/22815031?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 246878841,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/22815031/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--fTSatZ2h--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/22815031/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 33.54419904062836,
#    'lon': -117.33493460993,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$56,998',
#    'price_unformatted': 56998,
#    'mileage': '30,218 Miles',
#    'mileage_unformatted': 30218,
#    'city': 'Murrieta',
#    'state': 'CA',
#    'distance_from_origin': 8739,
#    'dealer_name': 'CarMax Murrieta - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EBXKF389006',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EBXKF389006',
#     'remote_dealer_id': '6002',
#     'dealer_name': 'CarMax Murrieta',
#     'remote_sku': '22815031',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_murrieta',
#     'dealer_uuid': '74ebbc19-84cf-4cec-8bac-af755b3cae1c',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Performance',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1660601777,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EAXKF476086',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXKF476086',
#    'clickoff_url': 'https://www.carmax.com/car/23100173?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 248800161,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23100173/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--0fzNHEZV--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23100173/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 36.056538,
#    'lon': -115.029068,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$51,998',
#    'price_unformatted': 51998,
#    'mileage': '7,739 Miles',
#    'mileage_unformatted': 7739,
#    'city': 'Henderson',
#    'state': 'NV',
#    'distance_from_origin': 8592,
#    'dealer_name': 'CarMax Henderson - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EAXKF476086',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EAXKF476086',
#     'remote_dealer_id': '7157',
#     'dealer_name': 'CarMax Henderson',
#     'remote_sku': '23100173',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_henderson',
#     'dealer_uuid': '06b5ea49-dcde-4bbc-bf40-8197f7a0277d',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1661595347,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA2KF312184',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA2KF312184',
#    'clickoff_url': 'https://www.carmax.com/car/23227183?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 249538486,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23227183/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--rmX1QB9D--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23227183/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 39.73684949543254,
#    'lon': -74.97498874634458,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$49,998',
#    'price_unformatted': 49998,
#    'mileage': '27,813 Miles',
#    'mileage_unformatted': 27813,
#    'city': 'Sicklerville',
#    'state': 'NJ',
#    'distance_from_origin': 7875,
#    'dealer_name': 'CarMax Turnersville - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA2KF312184',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA2KF312184',
#     'remote_dealer_id': '7234',
#     'dealer_name': 'CarMax Turnersville',
#     'remote_sku': '23227183',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_turnersville',
#     'dealer_uuid': '6c11c0ac-bea0-4934-a4c5-1c7a41abd405',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1661639409,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA4KF432181',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA4KF432181',
#    'clickoff_url': 'https://www.carmax.com/car/23100198?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 249585303,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23100198/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--JhBWmet4--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23100198/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 34.221963,
#    'lon': -119.153729,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$51,998',
#    'price_unformatted': 51998,
#    'mileage': '21,133 Miles',
#    'mileage_unformatted': 21133,
#    'city': 'Oxnard',
#    'state': 'CA',
#    'distance_from_origin': 8670,
#    'dealer_name': 'CarMax Oxnard - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA4KF432181',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA4KF432181',
#     'remote_dealer_id': '6014',
#     'dealer_name': 'CarMax Oxnard',
#     'remote_sku': '23100198',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_oxnard',
#     'dealer_uuid': 'dfee9eab-fb2c-4d95-b57b-61908c33aa04',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1662243332,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/7SAYGDEF3NF376769',
#    'vdp_url': '/tesla-model+y#vin=7SAYGDEF3NF376769',
#    'clickoff_url': 'https://www.carmax.com/car/23023630?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 250047211,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23023630/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--4i8vflft--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23023630/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 41.47438,
#    'lon': -87.320145,
#    'year': 2022,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$74,998',
#    'price_unformatted': 74998,
#    'mileage': '7,424 Miles',
#    'mileage_unformatted': 7424,
#    'city': 'Merrillville',
#    'state': 'IN',
#    'distance_from_origin': 8065,
#    'dealer_name': 'CarMax Merrillville - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '7SAYGDEF3NF376769',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '7SAYGDEF3NF376769',
#     'remote_dealer_id': '7180',
#     'dealer_name': 'CarMax Merrillville',
#     'remote_sku': '23023630',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_merrillville',
#     'dealer_uuid': '42eb263b-b517-48a3-8b78-1c161776ddd2',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Performance',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1661552170,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJYGDEE1MF098120',
#    'vdp_url': '/tesla-model+y#vin=5YJYGDEE1MF098120',
#    'clickoff_url': 'https://www.carmax.com/car/23051737?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 249502405,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23051737/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--FkQ0v01m--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23051737/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 34.07448266502487,
#    'lon': -117.6001690309131,
#    'year': 2021,
#    'make': 'Tesla',
#    'model': 'Model Y',
#    'model_id': 2357,
#    'display_color': '',
#    'price': '$70,998',
#    'price_unformatted': 70998,
#    'mileage': '28,551 Miles',
#    'mileage_unformatted': 28551,
#    'city': 'Ontario',
#    'state': 'CA',
#    'distance_from_origin': 8700,
#    'dealer_name': 'CarMax Ontario - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJYGDEE1MF098120',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJYGDEE1MF098120',
#     'remote_dealer_id': '7120',
#     'dealer_name': 'CarMax Ontario',
#     'remote_sku': '23051737',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_ontario',
#     'dealer_uuid': '4864be11-9c0d-40b6-a0c7-22984baefa73',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1662157011,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB1KF212666',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB1KF212666',
#    'clickoff_url': 'https://www.carmax.com/car/23315941?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 249973018,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23315941/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--5gdVnTmx--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23315941/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 37.691496,
#    'lon': -121.847734,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$53,998',
#    'price_unformatted': 53998,
#    'mileage': '33,237 Miles',
#    'mileage_unformatted': 33237,
#    'city': 'Pleasanton',
#    'state': 'CA',
#    'distance_from_origin': 8399,
#    'dealer_name': 'CarMax Pleasanton - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB1KF212666',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB1KF212666',
#     'remote_dealer_id': '6068',
#     'dealer_name': 'CarMax Pleasanton',
#     'remote_sku': '23315941',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_pleasanton',
#     'dealer_uuid': 'aa30dd9c-1b75-4a66-a7d3-078716560d2a',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1661897779,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EB7JF066918',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EB7JF066918',
#    'clickoff_url': 'https://www.carmax.com/car/23021848?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 249669764,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23021848/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--P2e0bvr9--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23021848/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 41.787811,
#    'lon': -72.663048,
#    'year': 2018,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$51,998',
#    'price_unformatted': 51998,
#    'mileage': '36,215 Miles',
#    'mileage_unformatted': 36215,
#    'city': 'Hartford',
#    'state': 'CT',
#    'distance_from_origin': 7690,
#    'dealer_name': 'CarMax Hartford - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EB7JF066918',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EB7JF066918',
#     'remote_dealer_id': '7286',
#     'dealer_name': 'CarMax Hartford',
#     'remote_sku': '23021848',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_hartford',
#     'dealer_uuid': '960d71ba-6d0c-47b0-a855-c79f4eea6bbc',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Long Range',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1661985072,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EA7KF444938',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EA7KF444938',
#    'clickoff_url': 'https://www.carmax.com/car/23227181?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 249789812,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/23227181/1.jpg?width=1024&watermark=LYCG_1c',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--2K83j4wb--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23227181/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c',
#    'lat': 37.691496,
#    'lon': -121.847734,
#    'year': 2019,
#    'make': 'Tesla',
#    'model': 'Model 3',
#    'model_id': 2217,
#    'display_color': '',
#    'price': '$47,998',
#    'price_unformatted': 47998,
#    'mileage': '41,181 Miles',
#    'mileage_unformatted': 41181,
#    'city': 'Pleasanton',
#    'state': 'CA',
#    'distance_from_origin': 8399,
#    'dealer_name': 'CarMax Pleasanton - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '5YJ3E1EA7KF444938',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '5YJ3E1EA7KF444938',
#     'remote_dealer_id': '6068',
#     'dealer_name': 'CarMax Pleasanton',
#     'remote_sku': '23227181',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_pleasanton',
#     'dealer_uuid': 'aa30dd9c-1b75-4a66-a7d3-078716560d2a',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'Standard Range Plus',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False}],
#  'html': {'search_results': '<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+y#vin=7SAYGDEE6NF462505"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--QBH-ymJb--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/22985144/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a)\' title=\'used 2022 Tesla Model Y Long Range White 7SAYGDEE6NF462505\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2022 Tesla Model Y Long Range</div>\n<div class=\'subtext\'>\n274 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Transfer Available</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$79,998</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $1,153/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+3#vin=5YJ3E1EB5KF389947"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--bgZYKItv--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/23080315/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1c)\' title=\'used 2019 Tesla Model 3 Long Range Blue 5YJ3E1EB5KF389947\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2019 Tesla Model 3 Long Range</div>\n<div class=\'subtext\'>\n32,634 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Transfer Available</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$53,998</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $778/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/tesla-model+y#vin=5YJYGDEF0LF014067"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' data-background-image=\'https://images.autolist.com/image/fetch/s--4p_Ibb-X--/c_fill,f_auto,q_auto,w_320/https:/ ...
#   'pagination': '<ul><li class="previous disabled"><a>Previous</a></li><li class="selected"><a>1</a></li><li data-page="2"><a>2</a></li><li data-page="3"><a>3</a></li><li data-page="4"><a>...</a></li><li data-page="25"><a>25</a></li><li data-page="26"><a>26</a></li><li data-page="2" class="next"><a>Next</a></li></ul>'}}

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
# Model
# Mileage
# Year
# Dealer Name
# Price
#

# %%
#Model
results_json['search_results'][0]['model']
# Out:
# 'Model Y'

# %%
#mileage
results_json['search_results'][0]['mileage']
# Out:
# '274 Miles'

# %%
#Year
results_json['search_results'][0]['year']
# Out:
# 2022

# %%
#Dealer name
results_json['search_results'][0]['dealer_name']
# Out:
# 'CarMax Loveland - Now Offering Curbside Pickup And Home Delivery'

# %%
#Price
results_json['search_results'][0]['price']
# Out:
# '$79,998'

# %%
result_items = results_json['search_results']

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []


for result in result_items:
    model.append(result['model'])
    mileage.append(result['mileage'])
    year.append(result['year'])
    dealer_name.append(result['dealer_name'])
    price.append(result['price'])

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
teslacars_df = pd.DataFrame({'model':model, 'mileage':mileage , 'year':year , 'dealer_name':dealer_name , 'price':price })

# %%
teslacars_df
# Out:
#       model       mileage  year  \
# 0   Model Y     274 Miles  2022
# 1   Model 3  32,634 Miles  2019
# 2   Model Y   6,701 Miles  2020
# 3   Model Y  26,296 Miles  2021
# 4   Model Y   9,772 Miles  2021
# 5   Model Y  10,360 Miles  2022
# 6   Model 3  31,200 Miles  2019
# 7   Model Y  10,307 Miles  2021
# 8   Model 3   2,813 Miles  2021
# 9   Model Y  27,897 Miles  2021
# 10  Model 3  10,523 Miles  2021
# 11  Model 3  30,218 Miles  2019
# 12  Model 3   7,739 Miles  2019
# 13  Model 3  27,813 Miles  2019
# 14  Model 3  21,133 Miles  2019
# 15  Model Y   7,424 Miles  2022
# 16  Model Y  28,551 Miles  2021
# 17  Model 3  33,237 Miles  2019
# 18  Model 3  36,215 Miles  2018
# 19  Model 3  41,181 Miles  2019
#
#                                           dealer_name    price
# 0   CarMax Loveland - Now Offering Curbside Pickup...  $79,998
# 1        CarMax Dayton - Now Offering Curbside Pickup  $53,998
# 2                           CarMax Fremont - Now Open  $72,998
# 3   CarMax Ft. Lauderdale - Now Offering Curbside ...  $69,998
# 4   CarMax Riverside - Now Offering Curbside Picku...  $69,998
# 5    CarMax Schaumburg - Now Offering Curbside Pickup  $72,998
# 6                           CarMax Fremont - Now Open  $53,998
# 7      CarMax Oak Lawn - Now Offering Curbside Pickup  $67,998
# 8   CarMax Ft. Myers - Now Offering Curbside Picku...  $55,998
# 9   CarMax Costa Mesa - Now Offering Curbside Pick...  $69,998
# 10  CarMax East Haven - Now Offering Curbside Pick...  $54,998
# 11  CarMax Murrieta - Now Offering Curbside Pickup...  $56,998
# 12  CarMax Henderson - Now Offering Curbside Picku...  $51,998
# 13  CarMax Turnersville - Now Offering Curbside Pi...  $49,998
# 14  CarMax Oxnard - Now Offering Curbside Pickup A...  $51,998
# 15  CarMax Merrillville - Now Offering Curbside Pi...  $74,998
# 16  CarMax Ontario - Now Offering Curbside Pickup ...  $70,998
# 17                       CarMax Pleasanton - Now Open  $53,998
# 18  CarMax Hartford - Now Offering Curbside Pickup...  $51,998
# 19                       CarMax Pleasanton - Now Open  $47,998

# %% [markdown]
# ### Step 9 - Scraping Multiple Pages (here: 10 pages to get 200 results)

# %%
model = []
mileage = []
year = []
dealer_name = []
price = []


for i in range(11):

    params = (
             ('make', 'Tesla'),
             ('location', 'Mumbai,%20MH'),
             ('latitude', '19.0748'),
             ('longitude','72.8856'),
             ('page', str(i))
          )

    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', params = params)
    
    results_json = response.json()
    
    result_items = results_json['search_results']
    
    for result in result_items:
        
        model.append(result['model'])
        
        mileage.append(result['mileage'])
        
        year.append(result['year'])
        
        dealer_name.append(result['dealer_name'])
        
        price.append(result['price'])

# %%
teslacars_final_df = pd.DataFrame({'model':model, 'mileage':mileage , 'year':year , 'dealer_name':dealer_name , 'price':price })

# %%
teslacars_final_df
# Out:
#        model       mileage  year  \
# 0    Model Y     274 Miles  2022
# 1    Model 3  32,634 Miles  2019
# 2    Model Y   6,701 Miles  2020
# 3    Model Y  26,296 Miles  2021
# 4    Model Y   9,772 Miles  2021
# ..       ...           ...   ...
# 195  Model Y   2,340 Miles  2022
# 196  Model S   3,278 Miles  2021
# 197  Model 3  25,392 Miles  2019
# 198  Model 3  10,845 Miles  2019
# 199  Model 3      36 Miles  2022
#
#                                            dealer_name     price
# 0    CarMax Loveland - Now Offering Curbside Pickup...   $79,998
# 1         CarMax Dayton - Now Offering Curbside Pickup   $53,998
# 2                            CarMax Fremont - Now Open   $72,998
# 3    CarMax Ft. Lauderdale - Now Offering Curbside ...   $68,998
# 4    CarMax Riverside - Now Offering Curbside Picku...   $69,998
# ..                                                 ...       ...
# 195                       CarMax Pleasanton - Now Open   $79,998
# 196                       CarMax Serramonte - Now Open  $124,998
# 197               CarMax Capitol Expressway - Now Open   $48,998
# 198  CarMax Phoenix-Gilbert - Now Offering Curbside...   $53,998
# 199  CarMax Canoga Park - Now Offering Curbside Pic...   $56,998
#
# [200 rows x 5 columns]

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
teslacars_final_df.to_excel('teslacars.xlsx', index = False)

# %% [markdown]
# ## Thank You!!!
